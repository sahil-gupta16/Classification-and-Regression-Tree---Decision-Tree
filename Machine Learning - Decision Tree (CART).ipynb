# %% [markdown]
# # Decision Tree (CART) :
# ## Classification Tree :

# %%
#Getting the required libraries
import numpy as np
import pandas as pd

#for train-test split
from sklearn.model_selection import train_test_split

#for fitting classification tree
from sklearn.tree import DecisionTreeClassifier

#for fitting regression tree
from sklearn.tree import DecisionTreeRegressor

#to create the confusion matrix
from sklearn.metrics import confusion_matrix

from sklearn import tree

# %%
# Set the working directory 
import os
os.chdir(r"C:\Users\Lenovo\Documents\Codes")
#Read the iris.csv data
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## Separating the target and the predictors

# %%
X = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y= iris['species']

# %%
## Train - test split(stratified sampling of y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state = 100)

# %%
#validation data(optional)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.3, stratify = y_train, random_state = 100)

# %%
#X_train, X_test, y_train, y_test

# %%
# Decision tree classifier with criterion gini index

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                                 max_depth = 3, min_samples_leaf = 5)

clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)

# %%
#Classifying the new observations

# %%
#Making predictions
y_pred = clf_gini.predict(X_test)
y_pred
# Out:
# array(['setosa', 'versicolor', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'versicolor', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'versicolor', 'versicolor', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'virginica', 'versicolor', 'versicolor', 'virginica',
#        'versicolor', 'versicolor', 'virginica', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'setosa', 'virginica', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'versicolor', 'virginica',
#        'setosa', 'setosa', 'setosa', 'versicolor', 'setosa', 'setosa',
#        'setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# Confusion Matrix

# %%
c = confusion_matrix(y_test, y_pred)
c
# Out:
# array([[15,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  3, 12]], dtype=int64)

# %%
clf_gini.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Measures of Accuracy

# %%
#to get the overall accuracy take the sum of diagonal and divide it by the sum of all elements in the matrix
(c[0,0]+c[1,1]+c[2,2])/np.sum(c) * 100
# Out:
# 93.33333333333333

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
c
# Out:
# array([[15,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  3, 12]], dtype=int64)

# %%
Sensitivity = TP/(TP+FN)

Specificity= TN/(FP+TN) 

Precision = TP/(TP+FP)

# %%
#Setosa as positive(rest all negative)
Sensitivity = 15/(15+0)

Specificity = 30/(0+30)

Precision = 15/(15+0)

# %%
#Versicolor as positive(rest all negative)

Sensitivity = 15/(15+0)

Specificity =  27/(3+27)

Precision = 15/(15+3)

# %%
#Virginica as positive(rest all negative)

Sensitivity 12/(12+3)

Specificity = 30/(0+30) 

Precision = 12/(12+0)

# %%
c[0,0]/np.sum(c[0,:])
# Out:
# 1.0

# %%
np.sum(c[2,:])
# Out:
# 15

# %%
# Set the working directory 
import os
os.chdir(r"C:\Users\Lenovo\Documents\Codes")
#Read the iris.csv data
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y= iris['species']

# %%
## Train - test split(stratified sampling of y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state = 100)

# %%
#validation data(optional)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.3, stratify = y_train, random_state = 100)

# %%
#X_train, X_test, y_train, y_test

# %%
# Decision tree classifier with criterion gini index

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                                 max_depth = 3, min_samples_leaf = 5)

clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)

# %%
#Making predictions
y_pred2 = clf_gini.predict(X_val)
y_pred2
# Out:
# array(['virginica', 'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa',
#        'virginica', 'virginica', 'setosa', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'virginica', 'virginica', 'versicolor', 'setosa',
#        'virginica', 'setosa'], dtype=object)

# %%
c = confusion_matrix(y_val, y_pred2)
c
# Out:
# array([[11,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
clf_gini.score(X_val, y_val)
# Out:
# 1.0

# %%
#accuracy
(c[0,0]+c[1,1]+c[2,2])/np.sum(c) * 100
# Out:
# 100.0

# %%
y_pred3 = clf_gini.predict(X_test)
y_pred3
# Out:
# array(['setosa', 'versicolor', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'versicolor', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'versicolor', 'versicolor', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'virginica', 'versicolor', 'versicolor', 'virginica',
#        'versicolor', 'versicolor', 'virginica', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'setosa', 'virginica', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'versicolor', 'virginica',
#        'setosa', 'setosa', 'setosa', 'versicolor', 'setosa', 'setosa',
#        'setosa', 'versicolor', 'virginica'], dtype=object)

# %%
c = confusion_matrix(y_test, y_pred3)
c
# Out:
# array([[15,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  3, 12]], dtype=int64)

# %%
#H.W figure out how to plot a decision tree algorithm in Python(interpret the tree)

# %%
feature_X = iris.columns[0:4]
feature_X
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
text_representation = tree.export_text(clf_gini)
print(text_representation)
# Out:
# |--- feature_2 <= 2.50
# |   |--- class: setosa
# |--- feature_2 >  2.50
# |   |--- feature_3 <= 1.65
# |   |   |--- feature_2 <= 4.75
# |   |   |   |--- class: versicolor
# |   |   |--- feature_2 >  4.75
# |   |   |   |--- class: versicolor
# |   |--- feature_3 >  1.65
# |   |   |--- feature_2 <= 5.05
# |   |   |   |--- class: virginica
# |   |   |--- feature_2 >  5.05
# |   |   |   |--- class: virginica

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(clf_gini,
                   feature_names=feature_X,  
                   class_names=np.unique(y_train),
                   filled=True)

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
list(np.unique(y_train))
# Out:
# ['setosa', 'versicolor', 'virginica']

# %% [markdown]
# # Regression Tree :

# %%
# Set the working directory 
import os
os.chdir(r"C:\Users\Lenovo\Documents\Codes")
#Read the iris.csv data
cars = pd.read_csv("cars.csv")
cars.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
X = cars[['Cylinders', 'Weight', 'Horsepower']]
y = cars['MPG']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
model = DecisionTreeRegressor(max_depth = 3, min_samples_leaf = 5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, min_samples_leaf=5)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([19.2483871 , 32.89833333, 25.4452381 , 25.4452381 , 25.74545455,
#        25.4452381 , 19.2483871 , 25.4452381 , 19.2483871 , 25.4452381 ,
#        32.89833333, 11.7       , 11.7       , 32.89833333, 25.4452381 ,
#        25.4452381 , 28.51071429, 19.2483871 , 25.74545455, 25.4452381 ,
#        25.4452381 , 25.4452381 , 25.4452381 , 28.51071429, 19.2483871 ,
#        15.12564103, 19.2483871 , 19.2483871 , 25.4452381 , 32.89833333,
#        19.2483871 , 19.2483871 , 25.74545455, 32.89833333, 15.12564103,
#        32.89833333, 19.2483871 , 25.4452381 , 19.2483871 , 11.7       ,
#        25.74545455, 32.89833333, 19.2483871 , 19.2483871 , 32.89833333,
#        25.4452381 , 15.12564103, 32.89833333, 25.4452381 , 19.2483871 ,
#        32.89833333, 28.91111111, 25.74545455, 11.7       , 11.7       ,
#        19.2483871 , 11.7       , 32.89833333, 19.2483871 , 15.12564103,
#        19.2483871 , 19.2483871 , 32.89833333, 19.2483871 , 19.2483871 ,
# ...

# %%
feature_X = cars.columns[[2,5,4]]
feature_X
# Out:
# Index(['Cylinders', 'Weight', 'Horsepower'], dtype='object')

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
#RMSE
np.sqrt(np.mean((np.array(y_test)-y_pred)**2))
# Out:
# 4.0609608091030545

# %%
#MAE
np.mean(np.abs((np.array(y_test)-y_pred)))
# Out:
# 2.8837908334100826
